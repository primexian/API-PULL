# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '9670225e-938b-4799-87be-bf9fda0fd837',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2022-06-11T05:22:32.607Z', 'error_code': 0, 'error_message': None, 'elapsed': 28, 'credit_count': 1, 'notice': None, 'total_count': 10007}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9528, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio'], 'max_supply': 21000000, 'circulating_supply': 19064337, 'total_supply': 19064337, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'last_updated': '2022-06-11T05:22:00.000Z', 'quote': {'USD': {'price': 29333.87413302173, 'volume_24h': 27606391060.90171, 'volume_change_24h': 13.3547, 'percent_change_1h': 0.1349329, 'percent_change_24h': -2.66807271, 'percent_change_7d': -1.17957355, 'percent_change_30d': 7.31882571, 'percent_change_60d': -26.67041045, 'percent_change_90d': -25.10971141, 'market_cap': 559230861987.5092, 'market_cap_dominance': 46.6738, 'fully_diluted_market_cap': 616011356793.46, 'last_updated': '2022-06-11T05:22:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5745, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable', 'pow', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'bnb-chain'], 'max_supply': None, 'circulating_supply': 121126663.3115, 'total_supply': 121126663.3115, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'last_updated': '2022-06-11T05:21:00.000Z', 'quote': {'USD': {'price': 1675.7727978087123, 'volume_24h': 17491686769.59368, 'volume_change_24h': 36.7804, 'percent_change_1h': 0.09174034, 'percent_change_24h': -6.60722209, 'percent_change_7d': -5.15528658, 'percent_change_30d': -9.17710183, 'percent_change_60d': -44.16789609, 'percent_change_90d': -35.25840856, 'market_cap': 202980767466.74625, 'market_cap_dominance': 16.9409, 'fully_diluted_market_cap': 202980767466.75, 'last_updated': '2022-06-11T05:21:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 34576, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin'], 'max_supply': None, 'circulating_supply': 72494981446.97955, 'total_supply': 79710622658.24379, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'}, 'cmc_rank': 3, 'self_reported_circulating_supply': None, 'self ...

# %%
##normilize the data
type(data)
##Which is in dictionary form
# Out:
# dict

# %%
#jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10

# %%
import pandas as pd 
pd.json_normalize(data["status"])
# Out:
#                   timestamp  error_code error_message  elapsed  credit_count  \
# 0  2022-06-11T05:22:32.607Z           0          None       28             1
#
#   notice  total_count
# 0   None        10007

# %%
pd.set_option('display.max_columns', None) 
##show all columns in api pulls instead of ... when u calling it

# %%
pd.json_normalize(data["data"])
# Out:
#       id             name symbol                  slug  num_market_pairs  \
# 0      1          Bitcoin    BTC               bitcoin              9528
# 1   1027         Ethereum    ETH              ethereum              5745
# 2    825           Tether   USDT                tether             34576
# 3   3408         USD Coin   USDC              usd-coin              4371
# 4   1839              BNB    BNB                   bnb               945
# 5   2010          Cardano    ADA               cardano               454
# 6     52              XRP    XRP                   xrp               737
# 7   4687      Binance USD   BUSD           binance-usd              3832
# 8   5426           Solana    SOL                solana               327
# 9     74         Dogecoin   DOGE              dogecoin               484
# 10  6636         Polkadot    DOT          polkadot-new               351
# 11  3717  Wrapped Bitcoin   WBTC       wrapped-bitcoin               448
# 12  1958             TRON    TRX                  tron               619
# 13  4943              Dai    DAI  multi-collateral-dai               992
# 14  5805        Avalanche   AVAX             avalanche               266
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2018-10-08T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2017-10-01T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2019-09-20T00:00:00.000Z
# 8   2020-04-10T00:00:00.000Z
# 9   2013-12-15T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2019-01-30T00:00:00.000Z
# 12  2017-09-13T00:00:00.000Z
# 13  2019-11-22T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [mineable, pow, smart-contracts, ethereum-ecos...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 4   [marketplace, centralized-exchange, payments, ...  1.651168e+08
# 5   [mineable, dpos, pos, platform, research, smar...  4.500000e+10
# 6   [medium-of-exchange, enterprise-solutions, bin...  1.000000e+11
# 7   [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 8   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 9   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 11  [medium-of-exchange, defi, wrapped-tokens, fan...           NaN
# 12       [media, payments, tron-ecosystem, bnb-chain]           NaN
# 13  [defi, stablecoin, ethereum-ecosystem, avalanc...           NaN
# 14  [defi, smart-contracts, polychain-capital-port...  7.200000e+08
#
#     circulating_supply  total_supply  platform  cmc_rank  \
# 0         1.906434e+07  1.906434e+07       NaN         1
# 1         1.211267e+08  1.211267e+08       NaN         2
# 2         7.249498e+10  7.971062e+10       NaN         3
# 3         5.389253e+10  5.389253e+10       NaN         4
# 4         1.632770e+08  1.632770e+08       NaN         5
# 5         3.375257e+10  3.427770e+10       NaN         6
# 6         4.834310e+10  9.998954e+10       NaN         7
# 7         1.801445e+10  1.801445e+10       NaN         8
# 8         3.420776e+08  5.116169e+08       NaN         9
# 9         1.326708e+11  1.326708e+11       NaN        10
# 10        9.875793e+08  1.103303e+09       NaN        11
# 11        2.739014e+05  2.739014e+05       NaN        12
# 12        9.279093e+10  9.279093e+10       NaN        13
# 13        7.055262e+09  7.055262e+09       NaN        14
# 14        2.809736e+08  4.042296e+08       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
# 5                                NaN                       NaN
# 6                                NaN                       NaN
# 7                                NaN                       NaN
# 8                                NaN                       NaN
# 9                                NaN                       NaN
# 10                      9.048698e+08              7.939418e+09
# 11                               NaN                       NaN
# 12                      7.165966e+10              5.713386e+09
# 13                               NaN                       NaN
# 14                               NaN                       NaN
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2022-06-11T05:22:00.000Z     29333.874133          2.760639e+10
# 1   2022-06-11T05:21:00.000Z      1675.772798          1.749169e+10
# 2   2022-06-11T05:21:00.000Z         0.999216          4.674622e+10
# 3   2022-06-11T05:21:00.000Z         1.000188          4.192579e+09
# 4   2022-06-11T05:21:00.000Z       289.475937          1.316124e+09
# 5   2022-06-11T05:21:00.000Z         0.594678          1.132103e+09
# 6   2022-06-11T05:22:00.000Z         0.385948          1.301456e+09
# 7   2022-06-11T05:22:00.000Z         0.999449          4.243926e+09
# 8   2022-06-11T05:21:00.000Z        37.706315          1.074670e+09
# 9   2022-06-11T05:22:00.000Z         0.076271          4.018765e+08
# 10  2022-06-11T05:22:00.000Z         8.774100          4.462524e+08
# 11  2022-06-11T05:21:00.000Z     29288.423364          2.436175e+08
# 12  2022-06-11T05:21:00.000Z         0.079729          7.362933e+08
# 13  2022-06-11T05:21:00.000Z         1.000235          2.682433e+08
# 14  2022-06-11T05:21:00.000Z        22.665253          4.957850e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       13.3547                     0.134933
# 1                       36.7804                     0.091740
# 2                       12.3305                     0.001242
# 3                       20.7744                     0.006792
# 4                       52.5183                    -0.056230
# 5                       20.6475                     1.065271
# 6                       34.4517                     0.220498
# 7                       -7.4565                    -0.173535
# 8                      -18.9002                     0.122255
# 9                       34.2641                     0.323469
# 10                      11.7520                     0.061712
# 11                      13.4138                     0.200208
# 12                       6.0968                     0.317647
# 13                      63.2029                     0.012776
# 14                       7.4489                     0.685415
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -2.668073                    -1.179574
# 1                      -6.607222                    -5.155287
# 2                      -0.003885                     0.009775
# 3                       0.022067                    -0.003827
# 4                      -1.084985                    -2.824524
# 5                      -5.700996                     5.723980
# 6                      -5.309703                    -1.228076
# 7                      -0.159095                    -0.040148
# 8                      -6.723333                     1.326525
# 9                      -3.929422                    -6.380184
# 10                     -6.055645                    -5.700539
# 11                     -2.785850                    -1.276300
# 12                     -2.174924                     1.401158
# 13                     -0.013694                     0.012727
# 14                     -8.208033                    -0.981112
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       7.318826                    -26.670410
# 1                      -9.177102                    -44.167896
# 2                       0.521099                     -0.097671
# 3                      -0.018601                      0.006873
# 4                      23.378654                    -28.287049
# 5                      41.710327                    -36.672427
# 6                       8.306326                    -45.152383
# 7                      -0.391064                     -0.213765
# 8                     -10.867425                    -62.884684
# 9                       3.060054                    -44.525221
# 10                     12.740575                    -50.173080
# 11                      8.817320                    -26.621610
# 12                      9.856123                     35.665050
# 13                     -0.009170                      0.018440
# 14                    -15.120325                    -70.410999
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                     -25.109711          5.592309e+11
# 1                     -35.258409          2.029808e+11
# 2                      -0.092680          7.243816e+10
# 3                       0.016087          5.390268e+10
# 4                     -22.893956          4.726476e+10
# 5                     -25.344677          2.007189e+10
# 6                     -51.635636          1.865791e+10
# 7                      -0.154709          1.800452e+10
# 8                     -54.269344          1.289849e+10
# 9                     -34.214989          1.011900e+10
# 10                    -51.465644          8.665119e+09
# 11                    -25.090320          8.022139e+09
# 12                     32.476670          7.398172e+09
# 13                      0.021564          7.056920e+09
# 14                    -68.285864          6.368337e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          46.6738                        6.160114e+11
# 1                          16.9409                        2.029808e+11
# 2                           6.0457                        7.964814e+10
# 3                           4.4950                        5.390268e+10
# 4                           3.9448                        4.779733e+10
# 5                           1.6752                        2.676049e+10
# 6                           1.5572                        3.859478e+10
# 7                           1.5027                        1.800452e+10
# 8                           1.0765                        1.929119e+10
# 9                           0.8438                        1.011900e+10
# 10                          0.7232                        9.680495e+09
# 11                          0.6695                        8.022139e+09
# 12                          0.6175                        7.398171e+09
# 13                          0.5890                        7.056920e+09
# 14                          0.5315                        1.631898e+10
#
#       quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0   2022-06-11T05:22:00.000Z          NaN           NaN             NaN
# 1   2022-06-11T05:21:00.000Z          NaN           NaN             NaN
# 2   2022-06-11T05:21:00.000Z       1027.0      Ethereum             ETH
# 3   2022-06-11T05:21:00.000Z       1027.0      Ethereum             ETH
# 4   2022-06-11T05:21:00.000Z          NaN           NaN             NaN
# 5   2022-06-11T05:21:00.000Z       1839.0           BNB             BNB
# 6   2022-06-11T05:22:00.000Z       1839.0           BNB             BNB
# 7   2022-06-11T05:22:00.000Z       1839.0           BNB             BNB
# 8   2022-06-11T05:21:00.000Z          NaN           NaN             NaN
# 9   2022-06-11T05:22:00.000Z          NaN           NaN             NaN
# 10  2022-06-11T05:22:00.000Z       2502.0   Huobi Token              HT
# 11  2022-06-11T05:21:00.000Z       1027.0      Ethereum             ETH
# 12  2022-06-11T05:21:00.000Z          NaN           NaN             NaN
# 13  2022-06-11T05:21:00.000Z       1027.0      Ethereum             ETH
# 14  2022-06-11T05:21:00.000Z       1839.0           BNB             BNB
#
#    platform.slug                      platform.token_address
# 0            NaN                                         NaN
# 1            NaN                                         NaN
# 2       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4            NaN                                         NaN
# 5            bnb  0x3ee2200efb3400fabb9aacf31297cbdd1d435d47
# 6            bnb  0x1d2f0da169ceb9fc7b3144628db156f3f6c60dbe
# 7            bnb                                    BUSD-BD1
# 8            NaN                                         NaN
# 9            NaN                                         NaN
# 10   huobi-token  0xa2c49cee16a5e5bdefde931107dc1fae9f7773e3
# 11      ethereum  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 12           NaN                                         NaN
# 13      ethereum  0x6b175474e89094c44da98b954eedeac495271d0f
# 14           bnb  0x1ce0c2827e2ef14d5c4f29a091d735a204794041
