# %%
from requests import Request, Session
from requests.exceptions import ConnectionError,Timeout, ConnectTimeout,TooManyRedirects

# %%
import json

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '9670225e-938b-4799-87be-bf9fda0fd837',
}

# %%
session = Session()
session.headers.update(headers)
try:
    response = session.get(url, params = parameters)
    data = json.loads(response.text)
    print(data)
except(ConnectionError,Timeout, ConnectTimeout,TooManyRedirects) as e:
    print(e)
# Out:
# {'status': {'timestamp': '2022-06-11T08:37:30.771Z', 'error_code': 0, 'error_message': None, 'elapsed': 122, 'credit_count': 1, 'notice': None, 'total_count': 10007}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9528, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'p
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df
# Out:
#       id             name symbol                  slug  num_market_pairs  \
# 0      1          Bitcoin    BTC               bitcoin              9528
# 1   1027         Ethereum    ETH              ethereum              5745
# 2    825           Tether   USDT                tether             34578
# 3   3408         USD Coin   USDC              usd-coin              4371
# 4   1839              BNB    BNB                   bnb               945
# 5   2010          Cardano    ADA               cardano               454
# 6     52              XRP    XRP                   xrp               737
# 7   4687      Binance USD   BUSD           binance-usd              3832
# 8   5426           Solana    SOL                solana               327
# 9     74         Dogecoin   DOGE              dogecoin               484
# 10  6636         Polkadot    DOT          polkadot-new               351
# 11  3717  Wrapped Bitcoin   WBTC       wrapped-bitcoin               448
# ...

# %%
df["timestamp"] = pd.to_datetime('now')
df
# Out:
#       id             name symbol                  slug  num_market_pairs  \
# 0      1          Bitcoin    BTC               bitcoin              9528
# 1   1027         Ethereum    ETH              ethereum              5745
# 2    825           Tether   USDT                tether             34578
# 3   3408         USD Coin   USDC              usd-coin              4371
# 4   1839              BNB    BNB                   bnb               945
# 5   2010          Cardano    ADA               cardano               454
# 6     52              XRP    XRP                   xrp               737
# 7   4687      Binance USD   BUSD           binance-usd              3832
# 8   5426           Solana    SOL                solana               327
# 9     74         Dogecoin   DOGE              dogecoin               484
# 10  6636         Polkadot    DOT          polkadot-new               351
# 11  3717  Wrapped Bitcoin   WBTC       wrapped-bitcoin               448
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '9670225e-938b-4799-87be-bf9fda0fd837',
    }
    session = Session()
    session.headers.update(headers)
    try:
        response = session.get(url, params = parameters)
        data = json.loads(response.text)
        print(data)
    except(ConnectionError,Timeout, ConnectTimeout,TooManyRedirects) as e:
        print(e)
        
    df2 = pd.json_normalize(data['data'])
    df["timestamp"] = pd.to_datetime('now')
    df = df.append(df2)

# %%
import os 
from time import time, sleep

for i in range(333):
    api_runner()
    print('Api runner complete')
    sleep(60)
exit()
# Out:
# {'status': {'timestamp': '2022-06-11T09:11:41.756Z', 'error_code': 0, 'error_message': None, 'elapsed': 25, 'credit_count': 1, 'notice': None, 'total_count': 10007}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9528, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
df
# Out:
#       id             name symbol                  slug  num_market_pairs  \
# 0      1          Bitcoin    BTC               bitcoin              9528
# 1   1027         Ethereum    ETH              ethereum              5745
# 2    825           Tether   USDT                tether             34578
# 3   3408         USD Coin   USDC              usd-coin              4371
# 4   1839              BNB    BNB                   bnb               945
# 5   2010          Cardano    ADA               cardano               454
# 6     52              XRP    XRP                   xrp               737
# 7   4687      Binance USD   BUSD           binance-usd              3832
# 8   5426           Solana    SOL                solana               327
# 9     74         Dogecoin   DOGE              dogecoin               484
# 10  6636         Polkadot    DOT          polkadot-new               351
# 11  3717  Wrapped Bitcoin   WBTC       wrapped-bitcoin               448
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
df
# Out:
#       id             name symbol                  slug  num_market_pairs  \
# 0      1          Bitcoin    BTC               bitcoin              9528
# 1   1027         Ethereum    ETH              ethereum              5745
# 2    825           Tether   USDT                tether             34578
# 3   3408         USD Coin   USDC              usd-coin              4371
# 4   1839              BNB    BNB                   bnb               945
# 5   2010          Cardano    ADA               cardano               454
# 6     52              XRP    XRP                   xrp               737
# 7   4687      Binance USD   BUSD           binance-usd              3832
# 8   5426           Solana    SOL                solana               327
# 9     74         Dogecoin   DOGE              dogecoin               484
# 10  6636         Polkadot    DOT          polkadot-new               351
# 11  3717  Wrapped Bitcoin   WBTC       wrapped-bitcoin               448
# ...

# %%
df3 = df.groupby('name', sort = False)[[ 'quote.USD.percent_change_1h', 'quote.USD.percent_change_24h',
       'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d',
       'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()
df3
# Out:
#                  quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                             -0.95264                      -3.29340
# Ethereum                            -3.72931                      -9.98699
# Tether                               0.00087                      -0.00153
# USD Coin                            -0.00993                       0.02008
# BNB                                 -1.55294                      -1.60508
# Cardano                             -2.05963                      -3.92586
# XRP                                 -1.22201                      -5.38004
# Binance USD                         -0.06111                      -0.18269
# Solana                              -1.94941                      -7.62017
# Dogecoin                            -1.30623                      -4.69647
# Polkadot                            -1.99735                      -5.39904
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin          quote.USD.percent_change_1h     -0.95264
#                  quote.USD.percent_change_24h    -3.29340
#                  quote.USD.percent_change_7d     -2.43505
#                  quote.USD.percent_change_30d     4.69665
#                  quote.USD.percent_change_60d   -27.71201
#                  quote.USD.percent_change_90d   -25.74953
# Ethereum         quote.USD.percent_change_1h     -3.72931
#                  quote.USD.percent_change_24h    -9.98699
#                  quote.USD.percent_change_7d     -9.49407
#                  quote.USD.percent_change_30d   -14.94338
#                  quote.USD.percent_change_60d   -46.85618
#                  quote.USD.percent_change_90d   -37.73502
# Tether           quote.USD.percent_change_1h      0.00087
#                  quote.USD.percent_change_24h    -0.00153
#                  quote.USD.percent_change_7d      0.00566
#                  quote.USD.percent_change_30d     1.83863
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name = 'values')
df5
# Out:
#                                                 values
# name
# Bitcoin         quote.USD.percent_change_1h   -0.95264
#                 quote.USD.percent_change_24h  -3.29340
#                 quote.USD.percent_change_7d   -2.43505
#                 quote.USD.percent_change_30d   4.69665
#                 quote.USD.percent_change_60d -27.71201
#                 quote.USD.percent_change_90d -25.74953
# Ethereum        quote.USD.percent_change_1h   -3.72931
#                 quote.USD.percent_change_24h  -9.98699
#                 quote.USD.percent_change_7d   -9.49407
#                 quote.USD.percent_change_30d -14.94338
#                 quote.USD.percent_change_60d -46.85618
#                 quote.USD.percent_change_90d -37.73502
# Tether          quote.USD.percent_change_1h    0.00087
#                 quote.USD.percent_change_24h  -0.00153
#                 quote.USD.percent_change_7d    0.00566
#                 quote.USD.percent_change_30d   1.83863
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))
df5.reset_index()
df6 = df5.reset_index()
df6
# Out:
#                name                       level_1    values
# 0           Bitcoin   quote.USD.percent_change_1h  -0.95264
# 1           Bitcoin  quote.USD.percent_change_24h  -3.29340
# 2           Bitcoin   quote.USD.percent_change_7d  -2.43505
# 3           Bitcoin  quote.USD.percent_change_30d   4.69665
# 4           Bitcoin  quote.USD.percent_change_60d -27.71201
# 5           Bitcoin  quote.USD.percent_change_90d -25.74953
# 6          Ethereum   quote.USD.percent_change_1h  -3.72931
# 7          Ethereum  quote.USD.percent_change_24h  -9.98699
# 8          Ethereum   quote.USD.percent_change_7d  -9.49407
# 9          Ethereum  quote.USD.percent_change_30d -14.94338
# 10         Ethereum  quote.USD.percent_change_60d -46.85618
# 11         Ethereum  quote.USD.percent_change_90d -37.73502
# 12           Tether   quote.USD.percent_change_1h   0.00087
# 13           Tether  quote.USD.percent_change_24h  -0.00153
# 14           Tether   quote.USD.percent_change_7d   0.00566
# ...

# %%
df7 = df6.rename(columns = {'level_1': 'Percent Change'})
df7
# Out:
#                name                Percent Change    values
# 0           Bitcoin   quote.USD.percent_change_1h  -0.95264
# 1           Bitcoin  quote.USD.percent_change_24h  -3.29340
# 2           Bitcoin   quote.USD.percent_change_7d  -2.43505
# 3           Bitcoin  quote.USD.percent_change_30d   4.69665
# 4           Bitcoin  quote.USD.percent_change_60d -27.71201
# 5           Bitcoin  quote.USD.percent_change_90d -25.74953
# 6          Ethereum   quote.USD.percent_change_1h  -3.72931
# 7          Ethereum  quote.USD.percent_change_24h  -9.98699
# 8          Ethereum   quote.USD.percent_change_7d  -9.49407
# 9          Ethereum  quote.USD.percent_change_30d -14.94338
# 10         Ethereum  quote.USD.percent_change_60d -46.85618
# 11         Ethereum  quote.USD.percent_change_90d -37.73502
# 12           Tether   quote.USD.percent_change_1h   0.00087
# 13           Tether  quote.USD.percent_change_24h  -0.00153
# 14           Tether   quote.USD.percent_change_7d   0.00566
# ...

# %%
df7['Percent Change'] = df7['Percent Change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7
df7['Percent Change'] = df7['Percent Change'].replace(['quote.USD.percent_change_1h'],['1h'])
df7
# Out:
#                name Percent Change    values
# 0           Bitcoin             1h  -0.95264
# 1           Bitcoin            24h  -3.29340
# 2           Bitcoin             7d  -2.43505
# 3           Bitcoin            30d   4.69665
# 4           Bitcoin            60d -27.71201
# 5           Bitcoin            90d -25.74953
# 6          Ethereum             1h  -3.72931
# 7          Ethereum            24h  -9.98699
# 8          Ethereum             7d  -9.49407
# 9          Ethereum            30d -14.94338
# 10         Ethereum            60d -46.85618
# 11         Ethereum            90d -37.73502
# 12           Tether             1h   0.00087
# 13           Tether            24h  -0.00153
# 14           Tether             7d   0.00566
# 15           Tether            30d   1.83863
# 16           Tether            60d  -0.10386
# 17           Tether            90d  -0.09508
# 18         USD Coin             1h  -0.00993
# 19         USD Coin            24h   0.02008
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='Percent Change', y='values', hue='name', data=df7, kind='point')

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      29270.87553 2022-06-11 09:14:44.293169
# 0  Bitcoin      28935.18445 2022-06-11 09:14:44.293169
# 0  Bitcoin      28940.28432 2022-06-11 09:14:44.293169
# 0  Bitcoin      28975.23763 2022-06-11 09:14:44.293169
# 0  Bitcoin      28972.46963                        NaT

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='quote.USD.price'>
